# %% [markdown]
# # Worksheet 16
#
# Name:  Thian Amarasekera
#
# UID: U91933393
#
# ### Topics
#
# - Support Vector Machines (Non-linear case)
#
# ## Support Vector Machines
#
# Follow along in class to implement the perceptron algorithm and create an animation of the algorithm.

# %% [markdown]
# a) As we saw in class, the form
# $$w^T x + b = 0$$
# while simple, does not expose the inner product `<x_i, x_j>` which we know `w` depends on, having done the math. This is critical to applying the "kernel trick" which allows for learning non-linear decision boundaries. Let's modify the above algorithm to use the form
# $$\sum_i \alpha_i <x_i, x> + b = 0$$

# %%
import numpy as np
from PIL import Image as im
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

TEMPFILE = "temp.png"
CENTERS = [[0, 1], [1, 0]]

epochs = 100
learning_rate = .05
expanding_rate = .99
retracting_rate = 1.1

X, labels = datasets.make_blobs(n_samples=10, centers=CENTERS, cluster_std=0.2, random_state=0)
Y = np.array(list(map(lambda x : -1 if x == 0 else 1, labels.tolist())))

alpha_i = np.zeros((len(X),))
b = 0

def snap(x, alpha_i, b, error):
    # create a mesh to plot in
    h = .01  # step size in the mesh
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    meshData = np.c_[xx.ravel(), yy.ravel()]
    cs = np.array([x for x in 'gb'])
    fig, ax = plt.subplots()
    ax.scatter(X[:,0],X[:,1],color=cs[labels].tolist(), s=50, alpha=0.8)

    if error:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='r',fill=False))
    else:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='y',fill=False))
   
    Z = predict_many(alpha_i, b, meshData)
    Z = np.array([0 if z <=0 else 1 for z in Z]).reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.5, cmap=plt.cm.Paired)
    fig.savefig(TEMPFILE)
    plt.close()
    return im.fromarray(np.asarray(im.open(TEMPFILE)))

def predict_many(alpha_i, b, Z):
    res = []
    for i in range(len(Z)):
        res.append(predict(alpha_i, b, Z[i]))
    return np.array(res)

def kernel(x, y):
    return np.dot(x, y)

def predict(alpha_i, b, x):
    res = 0
    for i in range(len(X)):
        res += alpha_i[i] * Y[i] * kernel(X[i], x)
    res += b
    return res

images = []
for _ in range(epochs):
    # pick a point from X at random
    i = np.random.randint(0, len(X))
    error = False
    x, y = X[i], Y[i]
    
    # calculate the prediction
    pred = predict(alpha_i, b, x)
    if y * pred <= 0:
        error = True
        alpha_i[i] += learning_rate
        b += learning_rate * y
    else:
        alpha_i[i] *= expanding_rate
        b *= expanding_rate

        
    images.append(snap(x, alpha_i, b, error))

images[0].save(
    'svm_dual.gif',
    optimize=False,
    save_all=True,
    append_images=images[1:],
    loop=0,
    duration=100
)

# %% [markdown]
# Write a configurable kernel function to apply in lieu of the dot product. Try it out on a dataset that is not linearly separable.

# %%
def polynomial(x_i, x_j, c, n):
    return (np.dot(x_i, x_j) + c) ** n

# %% [markdown]
# b) Assume we fit an SVM using a polynomial Kernel function and it seems to overfit the data. How would you adjust the tuning parameter `n` of the kernel function?

# %% [markdown]
# To avoid overfitting, we can increase the tuning parameter n of the kernel function, which will make the decision boundary more smooth and less likely to overfit the data.

# %% [markdown]
# c) Assume we fit an SVM using a RBF Kernel function and it seems to underfit the data. How would you adjust the tuning parameter `sigma` of the kernel function?

# %% [markdown]
# To avoid underfitting, we can decrease the tuning parameter sigma of the kernel function, which will make the decision boundary more complex and less likely to underfit the data.

# %% [markdown]
# d) Tune the parameter of a specific Kernel function, to fit an SVM (using your code above) to the following dataset:

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt("spiral.data")
x, y = data[:, :2], data[:, 2]

plt.scatter(x[:,0], x[:,1], c=y)

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image as im

TEMPFILE = "temp.png"

def snap(x, alpha_i, b, error):
    # create a mesh to plot in
    h = .01  # step size in the mesh
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                         np.arange(y_min, y_max, h))

    meshData = np.c_[xx.ravel(), yy.ravel()]
    cs = np.array([x for x in 'gb'])
    fig, ax = plt.subplots()

    # Assuming 'labels' is a list of categorical labels
    label_mapping = {'g': 0, 'b': 1}
    label_indices = [label_mapping[label] for label in labels]

    ax.scatter(X[:, 0], X[:, 1], color=cs[label_indices].tolist(), s=50, alpha=0.8)

    # ax.scatter(X[:,0],X[:,1],color=cs[labels].tolist(), s=50, alpha=0.8)

    if error:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='r',fill=False))
    else:
        ax.add_patch(plt.Circle((x[0], x[1]), .12, color='y',fill=False))
   
    # Z = predict_many(alpha_i, b, meshData)
    Z = predict_many(alpha_i, b, meshData, X, Y)

    Z = np.array([0 if z <=0 else 1 for z in Z]).reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=.5, cmap=plt.cm.Paired)
    fig.savefig(TEMPFILE)
    plt.close()
    return im.fromarray(np.asarray(im.open(TEMPFILE)))

def predict_many(alpha_i, b, meshData, X, Y):
    res = []
    for point in meshData:  # Iterate through each point in the mesh
        res.append(predict(alpha_i, b, point, X, Y))  # Predict using the point from the mesh
    return np.array(res)


def kernel(x, y):
    return np.dot(x, y)

def rbf_kernel(x, y, gamma):
    return np.exp(-gamma * np.linalg.norm(x - y) ** 2)

# def predict(alpha_i, b, x, X, Y):
#     res = 0
#     for i in range(len(X)):
#         res += alpha_i[i] * Y[i] * kernel(X[i], x)
#     res += b
#     return res

def predict(alpha_i, b, x, X, Y, gamma=0.5):
    res = 0
    for i in range(len(X)):
        res += alpha_i[i] * Y[i] * rbf_kernel(X[i], x, gamma)
    res += b
    return res

data = np.loadtxt("spiral.data")
X, Y = data[:, :2], data[:, 2]

epochs = 100
learning_rate = 0.05
expanding_rate = 0.99
retracting_rate = 1.1

alpha_i = np.zeros((len(X),))
b = 0
labels = np.random.choice(['g', 'b'], size=len(X))

images = []

for _ in range(epochs):
    # pick a point from X at random
    i = np.random.randint(0, len(X))
    error = False
    x, y = X[i], Y[i]
    
    # calculate the prediction
    pred = predict(alpha_i, b, x, X, Y)
    if y * pred <= 0:
        error = True
        alpha_i[i] += learning_rate
        b += learning_rate * y
    else:
        alpha_i[i] *= expanding_rate
        b *= expanding_rate

    images.append(snap(x, alpha_i, b, error))

images[0].save(
    'svm_spiral.gif',
    optimize=False,
    save_all=True,
    append_images=images[1:],
    loop=0,
    duration=100
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb Cell 12 line <cell line: 82>()
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=94'>95</a>         alpha_i[i] *= expanding_rate
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=95'>96</a>         b *= expanding_rate
# ---> <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=97'>98</a>     images.append(snap(x, alpha_i, b, error))
#     <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=99'>100</a> images[0].save(
#     <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=100'>101</a>     'svm_spiral.gif',
#     <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=101'>102</a>     optimize=False,
#    (...)
#     <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=105'>106</a>     duration=100
#     <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=106'>107</a> )
#
# /Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb Cell 12 line snap(x, alpha_i, b, error)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=29'>30</a>     ax.add_patch(plt.Circle((x[0], x[1]), .12, color='y',fill=False))
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=31'>32</a> # Z = predict_many(alpha_i, b, meshData)
# ---> <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=32'>33</a> Z = predict_many(alpha_i, b, meshData, X, Y)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=34'>35</a> Z = np.array([0 if z <=0 else 1 for z in Z]).reshape(xx.shape)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=35'>36</a> ax.contourf(xx, yy, Z, alpha=.5, cmap=plt.cm.Paired)
#
# /Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb Cell 12 line predict_many(alpha_i, b, meshData, X, Y)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=41'>42</a> res = []
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=42'>43</a> for point in meshData:  # Iterate through each point in the mesh
# ---> <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=43'>44</a>     res.append(predict(alpha_i, b, point, X, Y))  # Predict using the point from the mesh
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=44'>45</a> return np.array(res)
#
# /Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb Cell 12 line predict(alpha_i, b, x, X, Y, gamma)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=61'>62</a> res = 0
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=62'>63</a> for i in range(len(X)):
# ---> <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=63'>64</a>     res += alpha_i[i] * Y[i] * rbf_kernel(X[i], x, gamma)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=64'>65</a> res += b
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=65'>66</a> return res
#
# /Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb Cell 12 line rbf_kernel(x, y, gamma)
#      <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=50'>51</a> def rbf_kernel(x, y, gamma):
# ---> <a href='vscode-notebook-cell:/Users/thian/Desktop/Data-Science-Fundamentals/lecture_16/worksheet_16.ipynb#X14sZmlsZQ%3D%3D?line=51'>52</a>     return np.exp(-gamma * np.linalg.norm(x - y) ** 2)
#
# File <__array_function__ internals>:5, in norm(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/linalg/linalg.py:2531, in norm(x, ord, axis, keepdims)
#    2529 else:
#    2530     sqnorm = dot(x, x)
# -> 2531 ret = sqrt(sqnorm)
#    2532 if keepdims:
#    2533     ret = ret.reshape(ndim*[1])
#
# KeyboardInterrupt:
